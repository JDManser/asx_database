# %%
import pandas as pd
import os
import yfinance as yf
import psycopg2 as pg
from sqlalchemy import create_engine

# %%
conn = pg.connect(dbname="postgres", user="john")

# %%
cursor = conn.cursor()
select_codes = "select issuer_code from asx_database.listed_companies"
cursor.execute(select_codes)
codes = cursor.fetchall()

# %%
for code in codes:
    try: 
        data = yf.Ticker(code[0] + ".AX")
        history = data.history(period="max") 
        history.insert(0, 'issuer_code', code[0].upper())
        history = history.rename(columns = {'Open':'open_price', 'High':'high_price', 'Low':'low_price', 'Close':'close_price', 
                                            'Volume':'daily_volume', 'Dividends':'dividends', 'Stock Splits':'stock_splits'})
        history.index.names = ['transaction_date']
        engine = create_engine(r'postgresql://john:john@localhost/postgres')
        conn2 = engine.connect()
        history.to_sql('daily_price_data', engine, schema='asx_database', if_exists='append')
        conn2.close()
        print(code[0] + ".AX", "Data Inserted")
    except Exception:
        continue
# Out:
# MOQ.AX Data Inserted
# ONT.AX Data Inserted
# 14D.AX Data Inserted
# 1ST.AX Data Inserted
# T3D.AX Data Inserted
# TDI.AX Data Inserted
# TGP.AX Data Inserted
# TOT.AX Data Inserted
# TDO.AX Data Inserted
# DDD.AX Data Inserted
# 3PL.AX Data Inserted
# 4DX.AX Data Inserted
# 4DS.AX Data Inserted
# 5GN.AX Data Inserted
# 88E.AX Data Inserted
# 8CO.AX Data Inserted
# 8IH.AX Data Inserted
# 8EC.AX Data Inserted
# 8VI.AX Data Inserted
# 9SP.AX Data Inserted
# NNT.AX Data Inserted
# ACB.AX Data Inserted
# AYI.AX Data Inserted
# A2B.AX Data Inserted
# ABP.AX Data Inserted
# ABL.AX Data Inserted
# AEG.AX Data Inserted
# AJC.AX Data Inserted
# AKG.AX Data Inserted
# AX8.AX Data Inserted
# AX1.AX Data Inserted
# ACS.AX Data Inserted
# ACQ.AX Data Inserted
# ACF.AX Data Inserted
# ACR.AX Data Inserted
# ACW.AX Data Inserted
# AIV.AX Data Inserted
# ACU.AX Data Inserted
# AD1.AX Data Inserted
# ADA.AX Data Inserted
# ADH.AX Data Inserted
# 1AD.AX Data Inserted
# ADD.AX Data Inserted
# ...
